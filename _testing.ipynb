# %%
#imports
import numpy as np
import pandas as pd
import requests
import json
import os
import re
from bs4 import BeautifulSoup
import urllib
from pandas import json_normalize
from dotenv import load_dotenv
load_dotenv()
from IPython.display import Image

# %%
def requestRapidApi (endpoint,token= os.getenv("api_key")):
    
    baseUrl="http://www.omdbapi.com"
    url = baseUrl+endpoint

    headers = {
        "Authorization": f"token {token}"}

    res = requests.get(url, headers=headers)
    
    data = res.json()
    
    if res.status_code != 200:
        raise ValueError('Invalid api call')
    
    return data

# %%
url_omdb = "/?i=tt3896198&"
url_g =''

# %%
x =requestRapidApi(url_omdb)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-3a04fb1ac9cc> in <module>
# ----> 1 x =requestRapidApi(url_omdb)
#
# <ipython-input-2-b4714bba79e3> in requestRapidApi(endpoint, token)
#      12
#      13     if res.status_code != 200:
# ---> 14         raise ValueError('Invalid api call')
#      15
#      16     return data
#
# ValueError: Invalid api call

# %%
print(x)
df_omdb = pd.DataFrame(list(x.items()),columns = ['column1','column2'])
display(df_omdb)
#No encuentro ninguna API que me de la info que quiero, estoy teniendo problemas a la hora de pensar en 
#buenas ideas para añadir con la API.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-05e1de830195> in <module>
# ----> 1 print(x)
#       2 df_omdb = pd.DataFrame(list(x.items()),columns = ['column1','column2'])
#       3 display(df_omdb)
#       4 #No encuentro ninguna API que me de la info que quiero, estoy teniendo problemas a la hora de pensar en
#       5 #buenas ideas para añadir con la API.
#
# NameError: name 'x' is not defined

# %%
#Let's do some webscraping check if it becomes usefull
responseshows = requests.get("https://www.imdb.com/chart/tvmeter/?ref_=nv_tvv_mptv")
html = responseshows.text
soup = BeautifulSoup(responseshows.text, 'html.parser')
tagtitle = [title.text.replace(' ','').replace('\n','') for title in soup.find_all('td', class_="titleColumn")]
print(*tagtitle, sep='\n')
# Out:
# CobraKai(2018)1(6)
# TheBoys(2019)2(3)
# Lucifer(2016)3(2)
# RaisedbyWolves(2020)4(24)
# TheUmbrellaAcademy(2019)5(3)
# TerritorioLovecraft(2020)6(3)
# Yellowstone(2018)7(3)
# LamaldicióndeBlyManor(2020)8(136)
# Juegodetronos(2011)9(1)
# Sobrenatural(2005)10(7)
# Lacaza(2013)11(1)
# TheOffice(2005)12(1)
# AnatomíadeGrey(2005)13(1)
# Away(2020)14(389)
# Dark(2017)15(4)
# BreakingBad(2008)16(2)
# TheWalkingDead(2010)17(9)
# Los100(2014)18(2)
# Shameless(2011)19(1)
# Mentescriminales(2005)20(1)
# Vikingos(2013)21(2)
# C.B.Strike(2017)22(233)
# StrangerThings(2016)23(1)
# Schitt'sCreek(2015)24(nochange)
# PeakyBlinders(2013)25(2)
# Friends(1994)26(3)
# EljovenWallander(2020)27(684)
# TedLasso(2020)28(3)
# Community(2009)29(1)
# TheMandalorian(2019)30(28)
# Ozark(2017)31(1)
# NewGirl(2011)32(4)
# Fargo(2014)33(5)
# ModernFamily(2009)34(nochange)
# LaleyendadeKorra(2012)35(16)
# Kingdom(2014)36(3)
# DirtyJohn(2018)37(25)
# TheCrown(2016)38(7)
# AmericanHorrorStory(2011)39(9)
# Hijosdelaanarquía(2008)40(5)
# Lamateriaoscura(2019)41(21)
# BlackMirror(2011)42(5)
# BigBang(2007)43(1)
# Outlander(2014)44(1)
# Euphoria(2019)45(1)
# LosSoprano(1999)46(9)
# Lacasadepapel(2017)47(8)
# LamaldicióndeHillHouse(2018)48(50)
# BrooklynNine-Nine(2013)49(4)
# Dosbalasmuyperdidas(2020)50(35)
# TheWitcher(2019)51(12)
# Suits(2011)52(6)
# BetterCallSaul(2015)53(1)
# TheBlacklist(2013)54(3)
# Leyyorden:Unidaddevíctimasespeciales(1999)55(1)
# Crónicasvampíricas(2009)56(1)
# Navy:Investigacióncriminal(2003)57(2)
# TheLastKingdom(2015)58(5)
# Elcuentodelacriada(2017)59(4)
# Hoops(2020)60(51)
# Apocalipsis(2020)61(104)
# Cómodefenderaunasesino(2014)62(2)
# Westworld(2016)63(2)
# ParksandRecreation(2009)64(4)
# AgentesdeS.H.I.E.L.D.(2013)65(16)
# Avatar:LaleyendadeAang(2005)66(12)
# Cosasdehermanas(1994)67(1,149)
# Succession(2018)68(4)
# Buffy,cazavampiros(1997)69(11)
# Cleptómanas(2019)70(20)
# DoctorWho(2005)71(4)
# Perdidos(2004)72(5)
# LaschicasGilmore(2000)73(nochange)
# TheWire(Bajoescucha)(2002)74(3)
# Éraseunavez(2011)75(2)
# House(2004)76(2)
# PerryMason(2020)77(36)
# IHateSuzie(2020)78(59)
# Aashram(2020)79(405)
# Dexter(2006)80(1)
# Cómoconocíavuestramadre(2005)81(7)
# StarTrek:Lanuevageneración(1987)82(3)
# MasabaMasaba(2020)83(321)
# Homeland(2011)84(nochange)
# TheFlash(2014)85(24)
# DoomPatrol(2019)86(20)
# PrisonBreak(2005)87(5)
# LosasesinatosdeMidsomer(1997)88(2)
# TrueDetective(2014)89(2)
# Sherlock(2010)90(nochange)
# Glee(2009)91(8)
# Bones(2005)92(1)
# LineofDuty(2012)93(11)
# ElalaoestedelaCasaBlanca(1999)94(7)
# ZackSnyder'sJusticeLeague(2021)95(89)
# Watchmen(2019)96(27)
# AllorNothing:TottenhamHotspur(2020)97(1,786)
# ThisIsUs(2016)98(4)
# Gotham(2014)99(3)
# ColgadosenFiladelfia(2005)100(nochange)

# %%
url_trakt = "https://api.trakt.tv"

def requestTRAKT (endpoint,token= os.getenv("trakt_key")):
    
    baseUrl="https://api.trakt.tv"
    url = baseUrl+endpoint

    headers = {
        "Authorization": f"token {token}"}

    res = requests.get(url, headers=headers)
    
    data = res.json()
    
    if res.status_code != 200:
        raise ValueError('Invalid api call')
    
    return data

# %%
responsemovie = requests.get("https://www.imdb.com/chart/tvmeter/?ref_=nv_tvv_mptv")
html = responsemovie.text
soup = BeautifulSoup(responseshows.text, 'html.parser')
tagtitle = [title.text.replace(' ','').replace('\n','') for title in soup.find_all('td', class_="titleColumn")]
print(*tagtitle, sep='\n')
# Out:
# CobraKai(2018)1(6)
# TheBoys(2019)2(3)
# Lucifer(2016)3(2)
# RaisedbyWolves(2020)4(24)
# TheUmbrellaAcademy(2019)5(3)
# TerritorioLovecraft(2020)6(3)
# Yellowstone(2018)7(3)
# LamaldicióndeBlyManor(2020)8(136)
# Juegodetronos(2011)9(1)
# Sobrenatural(2005)10(7)
# Lacaza(2013)11(1)
# TheOffice(2005)12(1)
# AnatomíadeGrey(2005)13(1)
# Away(2020)14(389)
# Dark(2017)15(4)
# BreakingBad(2008)16(2)
# TheWalkingDead(2010)17(9)
# Los100(2014)18(2)
# Shameless(2011)19(1)
# Mentescriminales(2005)20(1)
# Vikingos(2013)21(2)
# C.B.Strike(2017)22(233)
# StrangerThings(2016)23(1)
# Schitt'sCreek(2015)24(nochange)
# PeakyBlinders(2013)25(2)
# Friends(1994)26(3)
# EljovenWallander(2020)27(684)
# TedLasso(2020)28(3)
# Community(2009)29(1)
# TheMandalorian(2019)30(28)
# Ozark(2017)31(1)
# NewGirl(2011)32(4)
# Fargo(2014)33(5)
# ModernFamily(2009)34(nochange)
# LaleyendadeKorra(2012)35(16)
# Kingdom(2014)36(3)
# DirtyJohn(2018)37(25)
# TheCrown(2016)38(7)
# AmericanHorrorStory(2011)39(9)
# Hijosdelaanarquía(2008)40(5)
# Lamateriaoscura(2019)41(21)
# BlackMirror(2011)42(5)
# BigBang(2007)43(1)
# Outlander(2014)44(1)
# Euphoria(2019)45(1)
# LosSoprano(1999)46(9)
# Lacasadepapel(2017)47(8)
# LamaldicióndeHillHouse(2018)48(50)
# BrooklynNine-Nine(2013)49(4)
# Dosbalasmuyperdidas(2020)50(35)
# TheWitcher(2019)51(12)
# Suits(2011)52(6)
# BetterCallSaul(2015)53(1)
# TheBlacklist(2013)54(3)
# Leyyorden:Unidaddevíctimasespeciales(1999)55(1)
# Crónicasvampíricas(2009)56(1)
# Navy:Investigacióncriminal(2003)57(2)
# TheLastKingdom(2015)58(5)
# Elcuentodelacriada(2017)59(4)
# Hoops(2020)60(51)
# Apocalipsis(2020)61(104)
# Cómodefenderaunasesino(2014)62(2)
# Westworld(2016)63(2)
# ParksandRecreation(2009)64(4)
# AgentesdeS.H.I.E.L.D.(2013)65(16)
# Avatar:LaleyendadeAang(2005)66(12)
# Cosasdehermanas(1994)67(1,149)
# Succession(2018)68(4)
# Buffy,cazavampiros(1997)69(11)
# Cleptómanas(2019)70(20)
# DoctorWho(2005)71(4)
# Perdidos(2004)72(5)
# LaschicasGilmore(2000)73(nochange)
# TheWire(Bajoescucha)(2002)74(3)
# Éraseunavez(2011)75(2)
# House(2004)76(2)
# PerryMason(2020)77(36)
# IHateSuzie(2020)78(59)
# Aashram(2020)79(405)
# Dexter(2006)80(1)
# Cómoconocíavuestramadre(2005)81(7)
# StarTrek:Lanuevageneración(1987)82(3)
# MasabaMasaba(2020)83(321)
# Homeland(2011)84(nochange)
# TheFlash(2014)85(24)
# DoomPatrol(2019)86(20)
# PrisonBreak(2005)87(5)
# LosasesinatosdeMidsomer(1997)88(2)
# TrueDetective(2014)89(2)
# Sherlock(2010)90(nochange)
# Glee(2009)91(8)
# Bones(2005)92(1)
# LineofDuty(2012)93(11)
# ElalaoestedelaCasaBlanca(1999)94(7)
# ZackSnyder'sJusticeLeague(2021)95(89)
# Watchmen(2019)96(27)
# AllorNothing:TottenhamHotspur(2020)97(1,786)
# ThisIsUs(2016)98(4)
# Gotham(2014)99(3)
# ColgadosenFiladelfia(2005)100(nochange)

# %%
url = "https://movies-tvshows-data-imdb.p.rapidapi.com/"
token = os.getenv("apikey")
querystring = {"imdb":"tt1375666","type":"get-movies-images-by-imdb"}

headers = {
    'x-rapidapi-host': "movies-tvshows-data-imdb.p.rapidapi.com",
    'x-rapidapi-key': token
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"title":"Inception","IMDB":"tt1375666","poster":"http:\/\/image.tmdb.org\/t\/p\/original\/9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg","fanart":"http:\/\/image.tmdb.org\/t\/p\/original\/s3TBrRGB1iav7gFOCNx3H31MoES.jpg","status":"OK","status_message":"Query was successful"}

# %%
from dotenv import load_dotenv
load_dotenv()
from IPython.display import Image

# %%
def requestIMG(code,token = os.getenv('apikey')):
    url = "https://movies-tvshows-data-imdb.p.rapidapi.com/"
    querystring = {"imdb":code,"type":"get-movies-images-by-imdb"}
    headers = {
         'x-rapidapi-host': "movies-tvshows-data-imdb.p.rapidapi.com",
         'x-rapidapi-key': token
          }
    response = requests.request("GET", url, headers=headers, params=querystring).json()
    imglink =response['poster']
    display(Image(imglink))

# %%
def requestART(code,token = os.getenv('apikey')):
    url = "https://movies-tvshows-data-imdb.p.rapidapi.com/"
    querystring = {"imdb":code,"type":"get-movies-images-by-imdb"}
    headers = {
         'x-rapidapi-host': "movies-tvshows-data-imdb.p.rapidapi.com",
         'x-rapidapi-key': token
          }
    response = requests.request("GET", url, headers=headers, params=querystring).json()
    imglink =response['fanart']
    display(Image(imglink))

# %%
def requestIMGs(code,token = os.getenv('apikey')):
    url = "https://movies-tvshows-data-imdb.p.rapidapi.com/"
    querystring = {"imdb":code,"type":"get-movies-images-by-imdb"}
    headers = {
         'x-rapidapi-host': "movies-tvshows-data-imdb.p.rapidapi.com",
         'x-rapidapi-key': token
          }
    response = requests.request("GET", url, headers=headers, params=querystring).json()
    imglink =response['poster']
    display(Image(imglink,width = 400, height = 200))

# %%
requestIMGs('tt2488496')

# %%
requestART('tt2488496')
