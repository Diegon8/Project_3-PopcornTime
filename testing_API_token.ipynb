# %%
#imports
import numpy as np
import pandas as pd
import requests
import json
import os
import re
from bs4 import BeautifulSoup
import urllib
from pandas import json_normalize

# %%
def requestRapidApi (endpoint,token= os.getenv("api_key")):
    
    baseUrl="http://www.omdbapi.com"
    url = baseUrl+endpoint

    headers = {
        "Authorization": f"token {token}"}

    res = requests.get(url, headers=headers)
    
    data = res.json()
    
    if res.status_code != 200:
        raise ValueError('Invalid api call')
    
    return data

# %%
url_omdb = "/?i=tt3896198&apikey=df30b4fb"
url_g =''

# %%
x =requestRapidApi(url_omdb)

# %%
print(x)
df_omdb = pd.DataFrame(list(x.items()),columns = ['column1','column2'])
display(df_omdb)
#Estoy teniendo un problema con las APIs con token, todas las que he encontrado me dan como resultado un único ejemplo 
#como aquí debajo, sólamente me está sacando datos de una película, lo que equivaldría a una sola fila de mi dataset
#original. Por lo tanto no me es útil
# Out:
# {'Title': 'Guardians of the Galaxy Vol. 2', 'Year': '2017', 'Rated': 'PG-13', 'Released': '05 May 2017', 'Runtime': '136 min', 'Genre': 'Action, Adventure, Comedy, Sci-Fi', 'Director': 'James Gunn', 'Writer': 'James Gunn, Dan Abnett (based on the Marvel comics by), Andy Lanning (based on the Marvel comics by), Steve Englehart (Star-Lord created by), Steve Gan (Star-Lord created by), Jim Starlin (Gamora and Drax created by), Stan Lee (Groot created by), Larry Lieber (Groot created by), Jack Kirby (Groot created by), Bill Mantlo (Rocket Raccoon created by), Keith Giffen (Rocket Raccoon created by), Steve Gerber (Howard the Duck created by), Val Mayerik (Howard the Duck created by)', 'Actors': 'Chris Pratt, Zoe Saldana, Dave Bautista, Vin Diesel', 'Plot': "The Guardians struggle to keep together as a team while dealing with their personal family issues, notably Star-Lord's encounter with his father the ambitious celestial being Ego.", 'Language': 'English', 'Country': 'USA', 'Awards': '
# ...

# %%
responseshows = requests.get("https://www.imdb.com/chart/tvmeter/?ref_=nv_tvv_mptv")
html = responseshows.text
soup = BeautifulSoup(responseshows.text, 'html.parser')
tagtitle = [title.text.replace(' ','').replace('\n','') for title in soup.find_all('td', class_="titleColumn")]
print(*tagtitle, sep='\n')
# Out:
# CobraKai(2018)1(6)
# TheBoys(2019)2(3)
# Lucifer(2016)3(2)
# RaisedbyWolves(2020)4(24)
# TheUmbrellaAcademy(2019)5(3)
# TerritorioLovecraft(2020)6(3)
# Yellowstone(2018)7(3)
# LamaldicióndeBlyManor(2020)8(136)
# Juegodetronos(2011)9(1)
# Sobrenatural(2005)10(7)
# Lacaza(2013)11(1)
# TheOffice(2005)12(1)
# AnatomíadeGrey(2005)13(1)
# Away(2020)14(389)
# Dark(2017)15(4)
# BreakingBad(2008)16(2)
# TheWalkingDead(2010)17(9)
# Los100(2014)18(2)
# Shameless(2011)19(1)
# Mentescriminales(2005)20(1)
# Vikingos(2013)21(2)
# C.B.Strike(2017)22(233)
# StrangerThings(2016)23(1)
# Schitt'sCreek(2015)24(nochange)
# PeakyBlinders(2013)25(2)
# Friends(1994)26(3)
# EljovenWallander(2020)27(684)
# TedLasso(2020)28(3)
# Community(2009)29(1)
# TheMandalorian(2019)30(28)
# Ozark(2017)31(1)
# NewGirl(2011)32(4)
# Fargo(2014)33(5)
# ModernFamily(2009)34(nochange)
# LaleyendadeKorra(2012)35(16)
# Kingdom(2014)36(3)
# DirtyJohn(2018)37(25)
# TheCrown(2016)38(7)
# AmericanHorrorStory(2011)39(9)
# ...

# %%
url_trakt = "https://api.trakt.tv"

def requestTRAKT (endpoint,token= os.getenv("trakt_key")):
    
    baseUrl="https://api.trakt.tv"
    url = baseUrl+endpoint

    headers = {
        "Authorization": f"token {token}"}

    res = requests.get(url, headers=headers)
    
    data = res.json()
    
    if res.status_code != 200:
        raise ValueError('Invalid api call')
    
    return data

# %%
def requestIMDB(title):  
        url = "https://imdb8.p.rapidapi.com/title/get-awards-summary"
        querystring = {"page":"1","r":"json","s":title}
        headers = {'x-rapidapi-host': "imdb8.p.rapidapi.com",'x-rapidapi-key': "3f7f8d3686msh339dce4858e690bp15ab77jsn23845c5a2549"}
        response = requests.request("GET", url, headers=headers, params=querystring)
        return(response.text)

# %%
requestIMDB('Game of thrones')
# Out:
# '400 - Bad Request'

# %%
responsemovie = requests.get("https://www.imdb.com/chart/tvmeter/?ref_=nv_tvv_mptv")
html = responsemovie.text
soup = BeautifulSoup(responseshows.text, 'html.parser')
tagtitle = [title.text.replace(' ','').replace('\n','') for title in soup.find_all('td', class_="titleColumn")]
print(*tagtitle, sep='\n')
# Out:
# CobraKai(2018)1(6)
# TheBoys(2019)2(3)
# Lucifer(2016)3(2)
# RaisedbyWolves(2020)4(24)
# TheUmbrellaAcademy(2019)5(3)
# TerritorioLovecraft(2020)6(3)
# Yellowstone(2018)7(3)
# LamaldicióndeBlyManor(2020)8(136)
# Juegodetronos(2011)9(1)
# Sobrenatural(2005)10(7)
# Lacaza(2013)11(1)
# TheOffice(2005)12(1)
# AnatomíadeGrey(2005)13(1)
# Away(2020)14(389)
# Dark(2017)15(4)
# BreakingBad(2008)16(2)
# TheWalkingDead(2010)17(9)
# Los100(2014)18(2)
# Shameless(2011)19(1)
# Mentescriminales(2005)20(1)
# Vikingos(2013)21(2)
# C.B.Strike(2017)22(233)
# StrangerThings(2016)23(1)
# Schitt'sCreek(2015)24(nochange)
# PeakyBlinders(2013)25(2)
# Friends(1994)26(3)
# EljovenWallander(2020)27(684)
# TedLasso(2020)28(3)
# Community(2009)29(1)
# TheMandalorian(2019)30(28)
# Ozark(2017)31(1)
# NewGirl(2011)32(4)
# Fargo(2014)33(5)
# ModernFamily(2009)34(nochange)
# LaleyendadeKorra(2012)35(16)
# Kingdom(2014)36(3)
# DirtyJohn(2018)37(25)
# TheCrown(2016)38(7)
# AmericanHorrorStory(2011)39(9)
# ...

# %%
url = "https://movies-tvshows-data-imdb.p.rapidapi.com/"
token = os.getenv("rapidapi_key")
querystring = {"imdb":"tt1375666","type":"get-movies-images-by-imdb"}

headers = {
    'x-rapidapi-host': "movies-tvshows-data-imdb.p.rapidapi.com",
    'x-rapidapi-key': token
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"message":"Missing RapidAPI application key. Go to https:\/\/docs.rapidapi.com\/docs\/keys to learn how to get your API application key."}

# %%
print(os.getenv("rapidapi_key"))
# Out:
# None

# %%
def requestIMDB(title):  
        url = "https://imdb8.p.rapidapi.com/title/get-awards-summary"
        querystring = {"page":"1","r":"json","s":title}
        headers = {'x-rapidapi-host': "imdb8.p.rapidapi.com",'x-rapidapi-key': "3f7f8d3686msh339dce4858e690bp15ab77jsn23845c5a2549"}
        response = requests.request("GET", url, headers=headers, params=querystring)
        return(response.text)

# %%
from dotenv import load_dotenv
load_dotenv()
from IPython.display import Image

# %%
def requestIMG(code,token = os.getenv('apikey')):
    url = "https://movies-tvshows-data-imdb.p.rapidapi.com/"
    querystring = {"imdb":code,"type":"get-movies-images-by-imdb"}
    headers = {
         'x-rapidapi-host': "movies-tvshows-data-imdb.p.rapidapi.com",
         'x-rapidapi-key': token
          }
    response = requests.request("GET", url, headers=headers, params=querystring).json()
    imglink =response['poster']
    display(Image(imglink))

# %%
def requestNameIMG(code,token = os.getenv('apikey')):
    url = "https://movies-tvshows-data-imdb.p.rapidapi.com/"
    querystring = {"imdb":code,"type":"get-movies-images-by-imdb"}
    headers = {
         'x-rapidapi-host': "movies-tvshows-data-imdb.p.rapidapi.com",
         'x-rapidapi-key': token
          }
    response = requests.request("GET", url, headers=headers, params=querystring).json()
    imglink =response['poster']
    display(Image(imglink))
